# %%
# Cell 1: Installs and Imports

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models
import torchvision.transforms as transforms
from transformers import AutoTokenizer, AutoModel, AutoConfig
from torch.optim.lr_scheduler import ReduceLROnPlateau
from PIL import Image
import json
import os
import random
import numpy as np
from tqdm.notebook import tqdm
import torch.nn.functional as F
import math
import time # For timing epochs
from py_vncorenlp import VnCoreNLP


print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA Device Name: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch Version: 2.6.0+cu124
# CUDA Available: True
# CUDA Device Name: NVIDIA GeForce RTX 4090

# %%
# Cell 2: Configuration Class (CFG)
# import torch
# import os

# ==============================================================================
# Configuration Class (CFG)
# ==============================================================================
class CFG:
    # --- Paths ---
    # /root/Tuning-CLIP/data/UIT-OpenViIC-dataset/images/00000000000.png
    # Base directory where your train.json, dev.json, test.json are located
    data_path = "./data/OpenViVQA-dataset/"
    image_path = "./data/OpenViVQA-dataset/"

    # Output directory for saved models
    model_path = "./clip_vi"

    # --- Available Models ---
    text_models = {
        "PhoBERT-base": "vinai/phobert-base",
        "PhoBERT-large": "vinai/phobert-large",
        "ViT5-base": "VietAI/vit5-base",
        "ViT5-large": "VietAI/vit5-large"
    }
    image_models = {
        "ViT-S": "vit_small_patch16_224", "ViT-B": "vit_base_patch16_224",
        "ViT-L": "vit_large_patch16_224", "ViT-H": "vit_huge_patch16_224",
        "ResNet50": "resnet50"
    }

    # --- User Selections ---
    selected_text_model = "PhoBERT-base"
    selected_image_model = "ResNet50"

    # --- Model parameters based on selection (Properties) ---
    @property
    def model_name(self): return self.image_models[self.selected_image_model]
    @property
    def text_encoder_model(self): return self.text_models[self.selected_text_model]
    @property
    def text_tokenizer(self): return self.text_models[self.selected_text_model]

    @property
    def text_embedding(self): # Encoder output dim before projection
        model_key = self.text_models[self.selected_text_model]
        if "large" in model_key: return 1024
        elif "base" in model_key: return 768
        else: print(f"Warning: Unknown text embedding size for {model_key}, defaulting to 768."); return 768

    @property
    def image_embedding(self): # Encoder output dim before projection
        if self.selected_image_model == "ResNet50": return 2048
        elif self.selected_image_model == "ViT-S": return 384
        elif self.selected_image_model == "ViT-B": return 768
        elif self.selected_image_model == "ViT-L": return 1024
        elif self.selected_image_model == "ViT-H": return 1280
        else: print(f"Warning: Unknown image embedding size for {self.model_name}, defaulting to 768."); return 768
    
    # --- Fixed parameters ---
    projection_dim = 256 # Shared latent space dimension

    # --- Training parameters ---
    seed = 42
    batch_size = 64
    num_workers = 20  
    head_lr = 5e-4
    image_encoder_lr = 3e-4
    text_encoder_lr = 5e-5
    weight_decay = 3e-3
    patience = 3
    factor = 0.8
    epochs = 32
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # --- Image/Text parameters ---
    size = 224 # Input image size
    max_length = 200 # Max text sequence length

    # --- Loss/Saving parameters ---
    temperature = 0.07
    save_best_only = True
    metric_to_track = "avg_acc"
    mode = "max" if metric_to_track != "loss" else "min"


# --- Instantiate Config and Create Output Dir ---
config = CFG()
os.makedirs(config.model_path, exist_ok=True)
print(f"Using device: {config.device}")
print(f"Model output path: {config.model_path}")
print(f"Image base path (for resolving paths in JSON): {os.path.abspath(config.image_path)}")
# Out:
# Using device: cuda
# Model output path: ./clip_vi
# Image base path (for resolving paths in JSON): /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset

# %%
# Cell 3: Seeding for Reproducibility

def set_seed(seed=config.seed):
    print(f"Setting seed: {seed}")
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For multi-GPU
        # These can slow down training, use cautiously if performance is critical
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed()
# Out:
# Setting seed: 42

# %%
# Cell 4: Metric Calculation Utilities

class AvgMeter:
    """Computes and stores the average and current value"""
    def __init__(self, name="Metric"):
        self.name = name
        self.reset()

    def reset(self):
        self.sum = 0
        self.count = 0
        self.avg = 0

    def update(self, val, count=1):
        # Ensure val is a scalar number before adding to sum
        if torch.is_tensor(val):
             val = val.item() # Convert tensor to Python number
        if isinstance(val, (int, float)):
            self.sum += val * count
            self.count += count
            self.avg = self.sum / self.count if self.count != 0 else 0
        # else:
            # Optionally print a warning if the value is not usable
            # print(f"Warning: Cannot update AvgMeter '{self.name}' with value type {type(val)}")


    def __repr__(self):
        text = f"{self.name}: {self.avg:.4f}"
        return text

def compute_recall_at_k(similarity_matrix, k, dim):
    n = similarity_matrix.shape[1-dim]
    correct_count = 0
    top_k_indices = torch.topk(similarity_matrix, k, dim=dim).indices
    ground_truth = torch.arange(n, device=similarity_matrix.device)

    if dim == 0: # I2T
        for img_idx in range(n):
            if ground_truth[img_idx] in top_k_indices[:, img_idx]:
                correct_count += 1
    elif dim == 1: # T2I
        for txt_idx in range(n):
             if ground_truth[txt_idx] in top_k_indices[txt_idx, :]:
                correct_count += 1
    else: raise ValueError("dim must be 0 or 1")
    return correct_count / n if n > 0 else 0.0

def compute_metrics(image_embeddings, text_embeddings):
    sim_matrix = text_embeddings @ image_embeddings.T
    sim_matrix = sim_matrix.float() # Ensure float for calculations
    n = sim_matrix.shape[0]
    if n == 0:
        # Return default zero metrics for empty batch
        return {
            "i2t_acc": 0.0, "t2i_acc": 0.0, "avg_acc": 0.0,
            "avg_cosine_sim": 0.0,
            "i2t_recall": {"R@1": 0.0, "R@5": 0.0, "R@10": 0.0},
            "t2i_recall": {"R@1": 0.0, "R@5": 0.0, "R@10": 0.0}
        }

    ground_truth = torch.arange(n, device=sim_matrix.device)
    i2t_preds = torch.argmax(sim_matrix, dim=0)
    t2i_preds = torch.argmax(sim_matrix, dim=1)
    i2t_acc = (i2t_preds == ground_truth).float().mean().item()
    t2i_acc = (t2i_preds == ground_truth).float().mean().item()
    avg_acc = (i2t_acc + t2i_acc) / 2
    avg_cosine_sim = torch.diagonal(sim_matrix).mean().item()

    i2t_recall = {}
    t2i_recall = {}
    recall_k_values = [k for k in [1, 5, 10] if k <= n]
    for k in recall_k_values:
        i2t_recall[f"R@{k}"] = compute_recall_at_k(sim_matrix, k, dim=0)
        t2i_recall[f"R@{k}"] = compute_recall_at_k(sim_matrix, k, dim=1)

    # Ensure all keys R@1, R@5, R@10 exist even if k>n
    for k in [1, 5, 10]:
        k_str = f"R@{k}"
        if k_str not in i2t_recall: i2t_recall[k_str] = 0.0
        if k_str not in t2i_recall: t2i_recall[k_str] = 0.0

    metrics = {
        "i2t_acc": i2t_acc, "t2i_acc": t2i_acc, "avg_acc": avg_acc,
        "avg_cosine_sim": avg_cosine_sim,
        "i2t_recall": i2t_recall, "t2i_recall": t2i_recall
    }
    return metrics

print("Metric utilities defined.")
# Out:
# Metric utilities defined.

# %%
# Cell 5: Dataset Class Definition

class ImageCaptionDataset(Dataset):
    def __init__(self, json_path, image_base_path, tokenizer, transforms, max_length):
        super().__init__()
        print(f"Attempting to load data from: {os.path.abspath(json_path)}")
        try:
            with open(json_path, 'r', encoding='utf-8') as f:
                self.data = json.load(f)
        except FileNotFoundError:
            print(f"ERROR: JSON file not found at {json_path}")
            print(f"       Please ensure '{json_path}' exists relative to your notebook or provide the full path.")
            self.data = []
            # Optionally raise error: raise FileNotFoundError(f"JSON file not found at {json_path}")
        except json.JSONDecodeError:
            print(f"Error: Could not decode JSON from {json_path}")
            self.data = []
        except Exception as e:
            print(f"An unexpected error occurred loading {json_path}: {e}")
            self.data = []

        print(f"Found {len(self.data)} samples in {os.path.basename(json_path)}.")
        self.image_base_path = image_base_path
        self.tokenizer = tokenizer
        self.transforms = transforms
        self.max_length = max_length
        # Optional: Check if the image base path exists
        if not os.path.isdir(self.image_base_path):
             print(f"WARNING: Image base path does not exist: {os.path.abspath(self.image_base_path)}")
             print(f"         Ensure 'image_path' in CFG points to the correct directory relative to your notebook.")


    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if idx >= len(self.data):
             raise IndexError("Index out of bounds")
        item = self.data[idx]
        relative_image_path = item.get('image_path', None) # Use .get for safety
        caption = item.get('caption', '') # Use .get for safety

        if relative_image_path is None:
            print(f"Warning: Missing 'image_path' for item at index {idx}. Returning dummy data.")
            image = torch.zeros((3, config.size, config.size))
        else:
            image_path = os.path.normpath(os.path.join(self.image_base_path, relative_image_path))
            # /root/Tuning-CLIP/data/UIT-OpenViIC-dataset/images/00000000000.png
            try:
                image = Image.open(image_path).convert('RGB')
                image = self.transforms(image)
            except FileNotFoundError:
                # Reduced verbosity for notebook, but keep essential info
                print(f"Warning: Img not found: {image_path}. Base: {self.image_base_path}, Rel: {relative_image_path}")
                image = torch.zeros((3, config.size, config.size))
            except Exception as e:
                print(f"Warning: Error loading image {image_path}: {e}")
                image = torch.zeros((3, config.size, config.size))

        text_inputs = self.tokenizer(
            caption, padding='max_length', truncation=True,
            max_length=self.max_length, return_tensors='pt'
        )
        input_ids = text_inputs['input_ids'].squeeze(0)
        attention_mask = text_inputs['attention_mask'].squeeze(0)

        if input_ids.dim() == 0: input_ids = input_ids.unsqueeze(0)
        if attention_mask.dim() == 0: attention_mask = attention_mask.unsqueeze(0)

        return {
            "image": image,
            "input_ids": input_ids,
            "attention_mask": attention_mask
        }

print("ImageCaptionDataset class defined.")
# Out:
# ImageCaptionDataset class defined.

# %%
# Cell 6: Model Component Definitions (Encoders, CLIP Model, Loss)

# --- Image Encoder ---
class ImageEncoder(nn.Module):
    def __init__(self, config, pretrained=True):
        super().__init__()
        self.config = config
        print(f"Initializing Image Encoder: {config.selected_image_model}")
        if config.selected_image_model == "ResNet50":
            weights = models.ResNet50_Weights.DEFAULT if pretrained else None
            self.model = models.resnet50(weights=weights)
            self.input_features = config.image_embedding
            self.model.fc = nn.Identity()
            print(f"  Loaded ResNet50 from torchvision. Input features: {self.input_features}")
        # --- Add ViT logic here if needed ---
        # elif "ViT" in config.selected_image_model:
        #     try:
        #         import timm
        #     except ImportError:
        #         print("Please install timm library ('pip install timm') to use ViT models.")
        #         raise
        #     print(f"  Loading {config.model_name} using timm.")
        #     self.model = timm.create_model(config.model_name, pretrained=pretrained)
        #     self.input_features = config.image_embedding # Should match timm model output before head
        #     # Verify input_features matches actual output if possible, e.g., self.model.embed_dim
        #     # print(f"    ViT embed_dim: {self.model.embed_dim}") # Example check
        #     self.model.head = nn.Identity() # Remove classification head
        #     print(f"    Removed head. Input features to projection: {self.input_features}")
        # --- End ViT logic ---
        else:
            raise ValueError(f"Unsupported image model type in config: {config.selected_image_model}")

        self.projection = nn.Linear(self.input_features, self.config.projection_dim)
        print(f"  Added projection head: {self.input_features} -> {self.config.projection_dim}")


    def forward(self, x):
        features = self.model(x)
        # ViT models might output class token + patch tokens, check model architecture
        # If using ViT, might need features = features[:, 0] to get class token
        features = features.view(features.size(0), -1) # Flatten if needed
        projected_features = self.projection(features)
        projected_features = F.normalize(projected_features, p=2, dim=-1)
        return projected_features

# --- Text Encoder ---
class TextEncoder(nn.Module):
    def __init__(self, config, pretrained=True):
        super().__init__()
        self.config = config
        self.input_features = config.text_embedding # Dim before projection
        print(f"Initializing Text Encoder: {config.text_encoder_model}")
        print(f"  Expected input features: {self.input_features}")
        if pretrained:
            self.model = AutoModel.from_pretrained(config.text_encoder_model)
        else:
            model_config = AutoConfig.from_pretrained(config.text_encoder_model)
            self.model = AutoModel.from_config(model_config)

        # Check if actual model hidden size matches config
        actual_hidden_size = self.model.config.hidden_size
        if actual_hidden_size != self.input_features:
             print(f"WARNING: Configured text_embedding ({self.input_features}) does not match actual model hidden size ({actual_hidden_size}). Using actual size for projection.")
             self.input_features = actual_hidden_size # Use actual size

        self.projection = nn.Linear(self.input_features, self.config.projection_dim)
        print(f"  Added projection head: {self.input_features} -> {self.config.projection_dim}")


    def forward(self, input_ids, attention_mask):
        if input_ids.dim() == 1: input_ids = input_ids.unsqueeze(0)
        if attention_mask.dim() == 1: attention_mask = attention_mask.unsqueeze(0)
        outputs = self.model(input_ids=input_ids, attention_mask=attention_mask)
        # Using [CLS] token embedding
        cls_embedding = outputs.last_hidden_state[:, 0, :]
        projected_features = self.projection(cls_embedding)
        projected_features = F.normalize(projected_features, p=2, dim=-1)
        return projected_features

# --- CLIP Model ---
class CLIPViModel(nn.Module):
    def __init__(self, image_encoder, text_encoder, config):
        super().__init__()
        self.image_encoder = image_encoder
        self.text_encoder = text_encoder
        self.temperature = config.temperature

    def forward(self, image, input_ids, attention_mask):
        image_features = self.image_encoder(image)
        text_features = self.text_encoder(input_ids, attention_mask)
        logit_scale = 1 / self.temperature
        logits_per_image = logit_scale * image_features @ text_features.t()
        logits_per_text = logits_per_image.t()
        return logits_per_image, logits_per_text, image_features, text_features

# --- Loss Function ---
def contrastive_loss(logits_per_image, logits_per_text):
    batch_size = logits_per_image.shape[0]
    if batch_size == 0: return torch.tensor(0.0, device=logits_per_image.device, requires_grad=True) # Handle empty batch
    labels = torch.arange(batch_size, device=logits_per_image.device)
    loss_img = F.cross_entropy(logits_per_image, labels)
    loss_txt = F.cross_entropy(logits_per_text, labels)
    total_loss = (loss_img + loss_txt) / 2.0
    return total_loss

print("Model components and loss function defined.")
# Out:
# Model components and loss function defined.

# %%
# Cell 7: Training and Validation Epoch Functions

def train_epoch(model, dataloader, optimizer, device, epoch_num):
    model.train()
    loss_meter = AvgMeter(f"Train Loss E{epoch_num}")
    # Using tqdm.notebook for progress bar
    progress_bar = tqdm(dataloader, desc=f"Training E{epoch_num}", leave=False, unit="batch")
    for batch in progress_bar:
        optimizer.zero_grad()
        images = batch['image'].to(device)
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        batch_size = images.size(0)
        if batch_size == 0: continue # Skip empty batches

        logits_per_image, logits_per_text, _, _ = model(images, input_ids, attention_mask)
        loss = contrastive_loss(logits_per_image, logits_per_text)
        loss.backward()
        optimizer.step()
        loss_meter.update(loss.item(), batch_size)
        progress_bar.set_postfix(loss=f"{loss_meter.avg:.4f}")

    return loss_meter.avg

def validate_epoch(model, dataloader, device, epoch_num):
    model.eval()
    # Initialize meters
    loss_meter = AvgMeter(f"Val Loss E{epoch_num}")
    acc_meter = AvgMeter(f"Val Acc E{epoch_num}")
    cos_sim_meter = AvgMeter(f"Val CosSim E{epoch_num}")
    # Initialize all potential recall meters
    recall_meters = {
        "i2t_R@1": AvgMeter(f"Val I2T R@1 E{epoch_num}"), "i2t_R@5": AvgMeter(f"Val I2T R@5 E{epoch_num}"), "i2t_R@10": AvgMeter(f"Val I2T R@10 E{epoch_num}"),
        "t2i_R@1": AvgMeter(f"Val T2I R@1 E{epoch_num}"), "t2i_R@5": AvgMeter(f"Val T2I R@5 E{epoch_num}"), "t2i_R@10": AvgMeter(f"Val T2I R@10 E{epoch_num}"),
    }

    progress_bar = tqdm(dataloader, desc=f"Validation E{epoch_num}", leave=False, unit="batch")
    with torch.no_grad():
        for batch in progress_bar:
            images = batch['image'].to(device)
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            batch_size = images.size(0)
            if batch_size == 0: continue # Skip empty batches

            logits_per_image, logits_per_text, image_features, text_features = model(images, input_ids, attention_mask)
            loss = contrastive_loss(logits_per_image, logits_per_text)
            metrics = compute_metrics(image_features, text_features)

            # Update meters
            loss_meter.update(loss.item(), batch_size)
            acc_meter.update(metrics["avg_acc"], batch_size)
            cos_sim_meter.update(metrics["avg_cosine_sim"], batch_size)
            for k_val, meter in recall_meters.items():
                 recall_type, recall_key = k_val.split('_') # 'i2t'/'t2i', 'R@k'
                 if recall_key in metrics[f"{recall_type}_recall"]:
                    meter.update(metrics[f"{recall_type}_recall"][recall_key], batch_size)

            progress_bar.set_postfix(loss=f"{loss_meter.avg:.4f}", acc=f"{acc_meter.avg:.3f}")

    # Collect results
    validation_results = {"loss": loss_meter.avg, "avg_acc": acc_meter.avg, "avg_cosine_sim": cos_sim_meter.avg}
    for k_val, meter in recall_meters.items():
         validation_results[k_val.replace("_", " ")] = meter.avg # Format key nicely

    return validation_results

print("Training and Validation epoch functions defined.")
# Out:
# Training and Validation epoch functions defined.

# %%
# Cell 8: Setup - Tokenizer and Transforms

# 1. Load Tokenizer
print(f"Loading Tokenizer: {config.text_tokenizer}")
try:
    tokenizer = AutoTokenizer.from_pretrained(config.text_tokenizer)
    print("Tokenizer loaded successfully.")
except Exception as e:
    print(f"ERROR loading tokenizer '{config.text_tokenizer}': {e}")
    print("Please ensure the model name is correct and you have internet access or the model is cached.")
    # Optionally raise the error to stop execution
    # raise e

# 2. Define Image Transforms
image_transforms = transforms.Compose([
    transforms.Resize(config.size),
    transforms.CenterCrop(config.size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), # ImageNet stats
])
print("Image transforms defined.")
# Out:
# Loading Tokenizer: vinai/phobert-base
# Tokenizer loaded successfully.
# Image transforms defined.

# %%
# Cell 9: Setup - Datasets and DataLoaders

print("\nCreating datasets...")
# Construct JSON paths using config.data_path
# /Users/quanghuypham/Desktop/CP_Glimpse/Tuning-CLIP/data/UIT-OpenViIC-dataset/test.json
train_json = f"{os.path.abspath(config.data_path)}/train.json"
dev_json = f"{os.path.abspath(config.data_path)}/dev.json"
test_json = f"{os.path.abspath(config.data_path)}/test.json"

# Make sure tokenizer is loaded before creating datasets
if 'tokenizer' not in globals():
     print("ERROR: Tokenizer not loaded. Please run the previous cell.")
else:
    train_dataset = ImageCaptionDataset(
        json_path=train_json, image_base_path=config.image_path,
        tokenizer=tokenizer, transforms=image_transforms, max_length=config.max_length
    )
    dev_dataset = ImageCaptionDataset(
        json_path=dev_json, image_base_path=config.image_path,
        tokenizer=tokenizer, transforms=image_transforms, max_length=config.max_length
    )

    # Basic checks after loading
    if not train_dataset.data:
        print("\nERROR: Failed to load training data. Check 'train_json' path and format.")
        # Optionally raise an error: raise ValueError("Training data failed to load")
    if not dev_dataset.data:
         print("\nWARNING: Failed to load validation data. Validation steps will be skipped.")

    print("\nCreating dataloaders...")
    num_workers = min(config.num_workers, os.cpu_count() if os.cpu_count() else 1)
    print(f"Using {num_workers} workers for DataLoaders.")

    train_loader = None
    if train_dataset.data:
        train_loader = DataLoader(
            train_dataset, batch_size=config.batch_size, shuffle=True,
            num_workers=num_workers, pin_memory=True if config.device == torch.device("cuda") else False,
            drop_last=False # Keep last incomplete batch for training
        )
        print(f"Train loader created with {len(train_loader)} batches.")

    dev_loader = None
    if dev_dataset.data:
        dev_loader = DataLoader(
            dev_dataset, batch_size=config.batch_size, shuffle=False,
            num_workers=num_workers, pin_memory=True if config.device == torch.device("cuda") else False,
            drop_last=False # Keep last incomplete batch for validation
        )
        print(f"Validation loader created with {len(dev_loader)} batches.")

    if not train_loader:
         print("\nERROR: Train loader could not be created. Cannot proceed.")
         # raise ValueError("Train loader creation failed")
# Out:
# Creating datasets...
# Attempting to load data from: /home/researcher/huypq69/TuningModels/data/OpenViVQA-dataset/train.json
# Found 18899 samples in train.json.
# WARNING: Image base path does not exist: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset
#          Ensure 'image_path' in CFG points to the correct directory relative to your notebook.
# Attempting to load data from: /home/researcher/huypq69/TuningModels/data/OpenViVQA-dataset/dev.json
# Found 2239 samples in dev.json.
# WARNING: Image base path does not exist: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset
#          Ensure 'image_path' in CFG points to the correct directory relative to your notebook.
#
# Creating dataloaders...
# Using 20 workers for DataLoaders.
# Train loader created with 296 batches.
# Validation loader created with 35 batches.

# %%
# Cell 10: Setup - Model, Optimizer, Scheduler

print("\nInitializing model components...")
try:
    image_encoder = ImageEncoder(config).to(config.device)
    text_encoder = TextEncoder(config).to(config.device)
    model = CLIPViModel(image_encoder, text_encoder, config).to(config.device)
    print(f"\nCLIPViModel initialized successfully on {config.device}.")
    num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Trainable parameters: {num_params / 1e6:.2f} M")

except Exception as e:
    print(f"ERROR initializing models: {e}")
    print("Check model names in CFG, internet connection, and available memory.")
    # raise e # Optionally stop execution

# --- Optimizer Setup ---
if 'model' in globals() : # Check if model was created
    print("\nSetting up optimizer...")
    image_encoder_params = list(model.image_encoder.model.parameters())
    image_head_params = list(model.image_encoder.projection.parameters())
    text_encoder_params = list(model.text_encoder.model.parameters())
    text_head_params = list(model.text_encoder.projection.parameters())

    print(f"  Param counts: ImgBase={len(image_encoder_params)}, ImgHead={len(image_head_params)}, TxtBase={len(text_encoder_params)}, TxtHead={len(text_head_params)}")

    optimizer_grouped_parameters = [
        {"params": [p for p in image_encoder_params if p.requires_grad], "lr": config.image_encoder_lr, "weight_decay": config.weight_decay},
        {"params": [p for p in image_head_params if p.requires_grad], "lr": config.head_lr, "weight_decay": config.weight_decay},
        {"params": [p for p in text_encoder_params if p.requires_grad], "lr": config.text_encoder_lr, "weight_decay": config.weight_decay},
        {"params": [p for p in text_head_params if p.requires_grad], "lr": config.head_lr, "weight_decay": config.weight_decay},
    ]

    # Filter out groups with no parameters (can happen if parts are frozen)
    optimizer_grouped_parameters = [g for g in optimizer_grouped_parameters if g['params']]

    if not optimizer_grouped_parameters:
         print("ERROR: No parameters found for the optimizer. Check model structure and requires_grad flags.")
         # raise ValueError("Optimizer has no parameters")
    else:
        optimizer = optim.AdamW(optimizer_grouped_parameters)
        print(f"Optimizer AdamW initialized.")

        # --- LR Scheduler Setup ---
        lr_scheduler = ReduceLROnPlateau(
            optimizer, mode=config.mode, # Use mode from config ('min' for loss, 'max' for acc/recall)
            factor=config.factor, patience=config.patience
        )
        print(f"LR Scheduler ReduceLROnPlateau initialized (mode='{config.mode}', factor={config.factor}, patience={config.patience})")
        
        # --- Early Stopping Setup ---
        early_stopping_patience = getattr(config, 'early_stopping_patience', 5) 
        early_stopping_min_delta = getattr(config, 'early_stopping_min_delta', 0.001)
        early_stopping_counter = 0
        print(f"Early stopping initialized (patience={early_stopping_patience}, min_delta={early_stopping_min_delta})")

else:
    print("ERROR: Model not initialized. Skipping optimizer/scheduler setup.")
# Out:
# Initializing model components...
# Initializing Image Encoder: ResNet50
#   Loaded ResNet50 from torchvision. Input features: 2048
#   Added projection head: 2048 -> 256
# Initializing Text Encoder: vinai/phobert-base
#   Expected input features: 768
#   Added projection head: 768 -> 256
#
# CLIPViModel initialized successfully on cuda.
# Trainable parameters: 159.23 M
#
# Setting up optimizer...
#   Param counts: ImgBase=159, ImgHead=2, TxtBase=199, TxtHead=2
# Optimizer AdamW initialized.
# LR Scheduler ReduceLROnPlateau initialized (mode='max', factor=0.8, patience=3)
# Early stopping initialized (patience=5, min_delta=0.001)

# %%
# Cell 11: Training Loop

if 'model' in globals() and 'train_loader' in globals() and 'optimizer' in globals(): # Check prerequisites
    print(f"\nStarting training for {config.epochs} epochs...")
    print(f"Tracking metric: '{config.metric_to_track}' (mode: {config.mode})")

    best_val_metric = -float('inf') if config.mode == "max" else float('inf')
    history = {'train_loss': [], 'validation_results': []}
    start_train_time = time.time()

    for epoch in range(config.epochs):
        epoch_start_time = time.time()
        print(f"\n--- Epoch {epoch+1}/{config.epochs} ---")
        # --- Training ---
        train_loss = train_epoch(model, train_loader, optimizer, config.device, epoch+1)
        history['train_loss'].append(train_loss)
        print(f"Epoch {epoch+1}: Train Loss = {train_loss:.4f}")

        # --- Validation ---
        val_results = {"loss": float('inf'), "avg_acc": 0.0} # Default if no validation
        if dev_loader:
            val_results = validate_epoch(model, dev_loader, config.device, epoch+1)
            history['validation_results'].append(val_results)
            # Print validation metrics
            print("  Validation Metrics:")
            metric_log_str = "  "
            for name, value in val_results.items():
                metric_log_str += f"{name}: {value:.4f} | "
            print(metric_log_str.strip(" | "))

            # Step the LR scheduler based on the tracked metric
            current_val_metric_for_scheduler = val_results.get(config.metric_to_track, None)
            if current_val_metric_for_scheduler is not None:
                 lr_scheduler.step(current_val_metric_for_scheduler)
                 current_lrs = [group['lr'] for group in optimizer.param_groups]
                 # Simplified LR print: print first + last group LR assuming Head LRs are same
                 print(f"  Current LRs: ImgEnc={current_lrs[0]:.2e}, Head={current_lrs[1]:.2e}, TxtEnc={current_lrs[2]:.2e}")
            else:
                 print(f"  Warning: Metric '{config.metric_to_track}' not found in validation results. Scheduler not stepped.")

        else:
             print("  Validation skipped.")
             history['validation_results'].append(None) # Append None if no validation

        # --- Save Checkpoint ---
        current_val_metric = val_results.get(config.metric_to_track, -float('inf') if config.mode == "max" else float('inf'))

        is_best = False
        if dev_loader: # Only compare if validation was done
            if config.mode == "max" and current_val_metric > best_val_metric:
                is_best = True
                best_val_metric = current_val_metric
            elif config.mode == "min" and current_val_metric < best_val_metric:
                is_best = True
                best_val_metric = current_val_metric

        # Prepare save dictionary
        save_dict = {
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': lr_scheduler.state_dict(),
            'train_loss': train_loss,
            'validation_results': val_results,
            'best_val_metric': best_val_metric, # Store the best metric value seen so far
            'metric_tracked': config.metric_to_track, # Store which metric was tracked
        }

        # Save logic
        if config.save_best_only and dev_loader:
            if is_best:
                best_checkpoint_path = os.path.join(config.model_path, "clip_vi_best.pt")
                torch.save(save_dict, best_checkpoint_path)
                print(f"  Saved Best Model (Epoch {epoch+1}, {config.metric_to_track}={current_val_metric:.4f}) to {best_checkpoint_path}")
        else: # Save every epoch if not save_best_only
            epoch_checkpoint_path = os.path.join(config.model_path, f"clip_vi_epoch_{epoch+1}.pt")
            torch.save(save_dict, epoch_checkpoint_path)
            print(f"  Saved Epoch {epoch+1} Checkpoint to {epoch_checkpoint_path}")
            if is_best and dev_loader: # Also save a copy as best if it's the best so far
                 best_checkpoint_path = os.path.join(config.model_path, "clip_vi_best.pt")
                 torch.save(save_dict, best_checkpoint_path)
                 print(f"  (Also saved as best model)")


        epoch_end_time = time.time()
        print(f"--- Epoch {epoch+1} Time: {epoch_end_time - epoch_start_time:.2f} seconds ---")


    # --- End of Training ---
    end_train_time = time.time()
    total_train_time = end_train_time - start_train_time
    print(f"\n=============== Training Finished ===============")
    print(f"Total Training Time: {total_train_time:.2f} seconds ({total_train_time/60:.2f} minutes)")
    final_model_path = os.path.join(config.model_path, 'clip_vi_final_epoch.pt')
    torch.save(save_dict, final_model_path) # Save the final epoch state regardless
    print(f"Final epoch model state saved to {final_model_path}")
    if config.save_best_only and dev_loader and os.path.exists(os.path.join(config.model_path, "clip_vi_best.pt")):
        print(f"Best model based on '{config.metric_to_track}' ({best_val_metric:.4f}) saved to: {os.path.join(config.model_path, 'clip_vi_best.pt')}")
    print(f"=================================================")

else:
    print("ERROR: Prerequisites for training (model, dataloader, optimizer) not met. Training loop skipped.")
# Out:
# Starting training for 32 epochs...
# Tracking metric: 'avg_acc' (mode: max)
#
# --- Epoch 1/32 ---
# Training E1:   0%|          | 0/296 [00:00<?, ?batch/s]
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009785.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009785.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004867.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004867.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007912.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007912.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004881.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004881.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001887.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001887.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009909.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009909.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006425.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006425.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002090.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002090.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009623.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009623.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009856.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009856.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009979.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009979.jpg
#
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007511.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007511.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006156.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006156.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006968.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006968.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010366.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010366.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006220.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006220.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003138.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003138.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006035.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006035.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004374.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004374.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001443.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001443.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002899.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002899.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006414.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006414.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001312.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001312.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010016.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010016.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002531.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002531.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006943.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006943.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002249.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002249.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010406.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010406.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007277.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007277.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004737.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004737.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002087.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002087.jpg
#
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003095.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003095.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001271.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001271.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009557.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009557.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000679.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000679.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009597.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009597.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005314.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005314.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006496.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006496.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005384.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005384.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009266.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009266.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007677.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007677.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004280.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004280.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009698.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009698.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002876.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002876.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005769.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005769.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004687.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004687.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010995.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010995.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008080.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008080.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005593.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005593.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010391.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010391.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000953.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000953.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006682.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006682.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008498.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008498.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005864.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005864.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006057.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006057.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009211.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009211.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006287.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006287.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005172.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005172.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005270.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005270.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001509.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001509.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001136.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001136.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006557.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006557.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009706.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009706.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007302.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007302.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004984.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004984.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002557.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002557.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000987.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000987.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005589.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005589.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008401.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008401.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009567.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009567.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006685.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006685.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008614.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008614.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008186.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008186.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002282.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002282.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008613.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008613.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006103.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006103.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001796.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001796.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002082.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002082.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009826.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009826.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005908.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005908.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004025.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004025.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009208.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009208.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000947.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000947.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004314.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004314.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006038.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006038.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010832.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010832.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007529.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007529.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002327.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002327.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001164.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001164.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010173.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010173.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002517.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002517.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009611.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009611.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003936.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003936.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002310.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002310.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000640.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000640.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010884.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010884.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007665.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007665.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009566.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009566.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006688.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006688.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001642.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001642.jpg
#
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001925.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001925.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008733.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008733.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002380.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002380.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009801.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009801.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008059.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008059.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008131.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008131.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009827.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009827.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009674.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009674.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001689.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001689.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005838.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005838.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009213.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009213.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000745.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000745.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009225.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009225.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002196.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002196.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010177.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010177.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005440.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005440.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006683.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006683.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002422.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002422.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001804.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001804.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002774.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002774.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009593.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009593.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009725.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009725.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003957.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003957.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006760.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006760.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007672.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007672.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002662.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002662.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004948.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004948.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010183.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010183.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001391.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001391.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003213.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003213.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002035.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002035.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005597.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005597.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001449.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001449.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008085.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008085.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000625.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000625.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007739.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007739.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006447.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006447.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004903.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004903.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009665.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009665.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004648.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004648.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005343.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005343.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006171.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006171.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008653.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008653.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006633.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006633.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001730.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001730.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009595.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009595.jpg
#
#
#
#
#
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005551.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005551.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009241.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009241.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002039.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002039.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003195.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003195.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002523.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002523.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002074.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002074.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005737.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005737.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005356.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005356.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006797.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006797.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002127.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002127.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009675.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009675.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005822.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005822.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008968.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008968.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000877.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000877.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008997.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008997.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004174.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004174.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001992.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001992.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006078.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006078.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001280.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001280.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009544.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009544.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004697.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004697.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009935.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009935.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000787.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000787.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004112.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004112.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007711.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007711.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004194.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004194.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005297.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005297.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010633.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010633.jpg
#
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005786.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005786.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002527.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002527.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002650.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002650.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001562.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001562.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010401.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010401.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005725.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005725.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000719.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000719.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010025.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010025.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004855.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004855.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009019.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009019.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000000692.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000000692.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009386.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009386.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004095.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004095.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008517.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008517.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006426.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006426.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006147.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006147.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001929.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001929.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008655.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008655.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005759.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005759.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010044.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010044.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009298.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009298.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008824.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008824.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006335.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006335.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009869.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009869.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008480.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008480.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009589.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009589.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006462.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006462.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010615.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010615.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004603.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004603.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004229.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004229.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005589.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005589.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008030.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008030.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006049.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006049.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004347.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004347.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002788.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002788.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001020.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001020.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002196.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002196.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004749.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004749.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006501.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006501.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001862.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001862.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005617.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005617.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002789.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002789.jpg
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010802.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010802.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001578.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001578.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001272.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001272.jpg
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007447.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007447.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005463.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005463.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003012.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003012.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007347.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007347.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005893.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005893.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005173.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005173.jpg
#
#
#
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004714.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004714.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002062.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002062.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001600.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001600.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009543.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009543.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007061.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007061.jpgWarning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007081.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007081.jpg
#
# ...
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010969.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010969.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008916.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008916.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009697.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009697.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003203.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003203.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001133.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001133.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004455.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004455.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002188.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002188.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007402.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007402.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002580.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002580.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004739.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004739.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009624.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009624.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004814.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004814.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002086.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002086.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004857.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004857.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004780.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004780.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001479.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001479.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004163.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004163.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009654.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009654.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002136.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002136.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003987.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003987.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001101.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001101.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000011148.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000011148.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004528.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004528.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002792.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002792.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007348.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007348.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002558.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002558.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007572.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007572.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005299.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005299.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002969.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002969.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004309.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004309.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002289.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002289.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010948.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010948.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010026.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010026.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001941.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001941.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004979.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004979.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001721.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001721.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001899.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001899.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010777.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010777.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005007.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005007.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006275.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006275.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009848.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009848.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000006031.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000006031.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000007442.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000007442.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005165.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005165.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000001105.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000001105.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005704.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005704.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002814.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002814.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002845.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002845.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000002040.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000002040.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000003222.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000003222.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000010678.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000010678.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000009438.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000009438.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000005173.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000005173.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000004715.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000004715.jpg
# Warning: Img not found: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset/images/000000008344.jpg. Base: /home/researcher/huypq69/Tuning-CLIP/data/OpenViVQA-dataset, Rel: ./images/000000008344.jpg
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 15
#      13 print(f"\n--- Epoch {epoch+1}/{config.epochs} ---")
#      14 # --- Training ---
# ---> 15 train_loss = train_epoch(model, train_loader, optimizer, config.device, epoch+1)
#      16 history['train_loss'].append(train_loss)
#      17 print(f"Epoch {epoch+1}: Train Loss = {train_loss:.4f}")
#
# Cell In[7], line 8, in train_epoch(model, dataloader, optimizer, device, epoch_num)
#       6 # Using tqdm.notebook for progress bar
#       7 progress_bar = tqdm(dataloader, desc=f"Training E{epoch_num}", leave=False, unit="batch")
# ----> 8 for batch in progress_bar:
#       9     optimizer.zero_grad()
#      10     images = batch['image'].to(device)
#
# File ~/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File ~/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1480, in _MultiProcessingDataLoaderIter._next_data(self)
#    1478 del self._task_info[idx]
#    1479 self._rcvd_idx += 1
# -> 1480 return self._process_data(data)
#
# File ~/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1505, in _MultiProcessingDataLoaderIter._process_data(self, data)
#    1503 self._try_put_index()
#    1504 if isinstance(data, ExceptionWrapper):
# -> 1505     data.reraise()
#    1506 return data
#
# File ~/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/_utils.py:733, in ExceptionWrapper.reraise(self)
#     729 except TypeError:
#     730     # If the exception takes multiple arguments, don't try to
#     731     # instantiate since we don't know how to
#     732     raise RuntimeError(msg) from None
# --> 733 raise exception
#
# RuntimeError: Caught RuntimeError in DataLoader worker process 1.
# Original Traceback (most recent call last):
#   File "/home/researcher/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/worker.py", line 349, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/researcher/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/researcher/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py", line 398, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/researcher/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py", line 172, in collate
#     key: collate(
#          ^^^^^^^^
#   File "/home/researcher/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py", line 155, in collate
#     return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/researcher/huypq69/Tuning-CLIP/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py", line 272, in collate_tensor_fn
#     return torch.stack(batch, 0, out=out)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: stack expects each tensor to be equal size, but got [200] at entry 0 and [3, 200] at entry 55

# %%
# Cell 12: Final Evaluation on Test Set

print("\n=============== Starting Test Set Evaluation ===============")

test_json_path = os.path.join(config.data_path, "test.json")

if os.path.exists(test_json_path) and 'tokenizer' in globals():
    print(f"Loading test data from: {test_json_path}")
    test_dataset = ImageCaptionDataset(
        json_path=test_json_path, image_base_path=config.image_path,
        tokenizer=tokenizer, transforms=image_transforms, max_length=config.max_length
    )

    if test_dataset.data:
        num_workers = min(config.num_workers, os.cpu_count() if os.cpu_count() else 1)
        test_loader = DataLoader(
            test_dataset, batch_size=config.batch_size, shuffle=False,
            num_workers=num_workers, pin_memory=True if config.device == torch.device("cuda") else False,
            drop_last=False
        )
        print(f"Test loader created with {len(test_loader)} batches.")

        # --- Load Model for Testing ---
        # Create a fresh model instance
        try:
            test_image_encoder = ImageEncoder(config).to(config.device)
            test_text_encoder = TextEncoder(config).to(config.device)
            model_to_test = CLIPViModel(test_image_encoder, test_text_encoder, config).to(config.device)
            print("Model structure for testing created.")
        except Exception as e:
            print(f"ERROR creating model structure for testing: {e}")
            model_to_test = None # Prevent loading if structure fails

        if model_to_test:
            # Determine which model weights to load (best or final)
            best_model_path = os.path.join(config.model_path, "clip_vi_best.pt")
            final_model_path = os.path.join(config.model_path, "clip_vi_final_epoch.pt") # Use final epoch saved name

            load_path = None
            if os.path.exists(best_model_path):
                load_path = best_model_path
                print(f"Attempting to load best model weights from: {load_path}")
            elif os.path.exists(final_model_path):
                load_path = final_model_path
                print(f"Best model not found. Attempting to load final epoch weights from: {load_path}")
            else:
                print("WARNING: No saved model checkpoints ('best' or 'final') found in output directory.")
                print("         Evaluation will not be performed.")

            if load_path:
                try:
                    checkpoint = torch.load(load_path, map_location=config.device)
                    state_dict = checkpoint['model_state_dict']
                    # Handle potential 'module.' prefix if saved with DataParallel or DDP
                    if next(iter(state_dict)).startswith('module.'):
                        print("Detected 'module.' prefix, removing for loading.")
                        from collections import OrderedDict
                        new_state_dict = OrderedDict((k[7:], v) for k, v in state_dict.items())
                        model_to_test.load_state_dict(new_state_dict)
                    else:
                        model_to_test.load_state_dict(state_dict)
                    print(f"Model weights loaded successfully from {load_path}")

                    # --- Run Evaluation ---
                    print("\nRunning evaluation on test set...")
                    test_results = validate_epoch(model_to_test, test_loader, config.device, epoch_num="Test") # Use validate func

                    print("\n--- Test Set Results ---")
                    metric_log_str = ""
                    for name, value in test_results.items():
                        metric_log_str += f"  {name}: {value:.4f}\n"
                    print(metric_log_str.strip())
                    print("------------------------")

                except Exception as e:
                    print(f"\nERROR loading model weights or running evaluation from {load_path}: {e}")
                    import traceback
                    traceback.print_exc() # Print detailed traceback
            # --- End Model Loading/Eval ---
        # --- End Model Structure Check ---
    else:
         print("Could not load test data. Skipping test evaluation.")
else:
    if not os.path.exists(test_json_path):
         print(f"\nTest JSON path not found ({test_json_path}). Skipping test evaluation.")
    if 'tokenizer' not in globals():
         print("\nTokenizer not available. Skipping test evaluation.")

print("\n================= Evaluation Finished =================")
